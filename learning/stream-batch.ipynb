# %%
import os
from dotenv import load_dotenv
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model_name="llama-3.3-70b-versatile")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000020918FD0C20>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020918FD1940>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# lets invoke the above llm model

model.invoke("what is capital of india?")
# Out:
# AIMessage(content='The capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 41, 'total_tokens': 52, 'completion_time': 0.024176801, 'completion_tokens_details': None, 'prompt_time': 0.001192402, 'prompt_tokens_details': None, 'queue_time': 0.058288372, 'total_time': 0.025369203}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e6feb-2274-7ee2-9757-f0601d117f6e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 11, 'total_tokens': 52})

# %%
response=model.stream("what is capital of india?")
response
# Out:
# <generator object BaseChatModel.stream at 0x000002091A0B1590>

# %%
# you can see above that stream ne output nhi blki object i.e iterator return kiya
# now for seeing the text wee need to iterate using for loop on the response given by STREAM()

for chunk in response:
    print(chunk)
# Out:
# content='' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='The' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' capital' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' of' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' India' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' is' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' **' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='New' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' Delhi' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='**' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='.' additional_kwargs={} response_metadata={'model_provider': 'groq'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand'} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 41, 'output_tokens': 11, 'total_tokens': 52} tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={} id='lc_run--019e6fed-09a5-7f62-a765-9351b4bc4272' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[] chunk_position='last'

# %%
# above you can see the response is coming in chunks as it is streaming response.
for chunk in response:
    print(chunk.content,flush=True)
# Out:
# The
#  capital
#  of
#  India
#  is
#  **
# New
#  Delhi
# **
# .
